# %% [markdown]
# # SGLang
#
# ## RadixAttention

# %% [markdown]
# ## DP-Attention
#
# ### What is DP Attention?
#
# **Main idea:**
#
# 【Adventages】
# - Save memory space from duplicated KV cache
# - Bigger batch size
#
# ### What kind of models can be optimized via DP-Attention?
#
#
# ### Implementation
#
# #### Native
#
# #### SGLang Model Gateway

# %% [markdown]
# ## references
#
# 1.(SGLang Doc) DP, DPA and SGLang routers, https://docs.sglang.io/docs/advanced_features/dp_dpa_smg_guide
