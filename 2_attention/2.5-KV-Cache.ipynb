# %% [markdown]
# # KV Cache
#
# - [ ] Cache layout and paging
# - [ ] Prefix cache reuse
# - [ ] Cache quantization
#
# ## What is KV cache?
#
# What is KV cache? What does KV cache truely store?
#
# ![](../figs/3.2-KV-cache.gif)
#
# *This picture is how attention is computed when every new token inputs. (From @joao-lages's blog, see **Reference 1**)*
#
# We can conculde that: **The reason why we store KV projection to avoid recomputation is CAUSAL MASK.**

# %%
import torch

input_sequence_len = 10
hidden_dim = 64

X = torch.tensor(input_sequence_len, hidden_dim)

W_q = torch.randn(hidden_dim, hidden_dim)
W_k = torch.randn(hidden_dim, hidden_dim)
W_v = torch.randn(hidden_dim, hidden_dim)

Q = X @ W_q
K = X @ W_k
V = X @ W_v

# attention calculation


# calculate with KV cache

# %% [markdown]
# ## How to store?
#
# in what format? layout? paging?

# %% [markdown]
# ## references
#
# 1. (blog) Transformers KV Caching Explained, https://medium.com/@joaolages/kv-caching-explained-276520203249
