# %% [markdown]
# # 1.0 GPU & Profile
#
# ## GPU structure
#
# SM(Streaming Multiprocessor)
#
# SP(Streaming Processor)

# %% [markdown]
# ## GPU acceleration methods
#
# - control divergence
# - low precision computation
# - operator fusion
# - coalescing memory
# - recomputation: only in training, reduce the middle result stored.
# - **tiling**

# %% [markdown]
# ## How to profile GPU
