# %% [markdown]
# # 1.1-Operators-GEMM
#
# ## Pre: GPU & CUDA programming

# %% [markdown]
# ## Profiler

# %% [markdown]
# ## SetUp
# GEMM is short for General Matrix Multiplication.
# GEMM是通用矩阵乘法的缩写。
#
# $A\in R^{m\times k}, B\in R^{k\times n}, C = A \times B, C\in R^{m\times n}$

# %%
import torch

x = torch.rand(5,3)
print(x)
# Out:
# tensor([[0.2852, 0.5153, 0.9567],
#         [0.2332, 0.9580, 0.9614],
#         [0.3641, 0.1681, 0.5343],
#         [0.2273, 0.4131, 0.9100],
#         [0.7245, 0.8356, 0.6337]])
